# %%
import tensorflow

from keras.models import Sequential

model = Sequential()

# %%
import numpy as np

# %%
np.unique([1,1,2,3,4,4,3,1,])
# Out:
# array([1, 2, 3, 4])

# %%
np.unique([1,1,2,3,4,4,3,1,], return_inverse=True)
# Out:
# (array([1, 2, 3, 4]), array([0, 0, 1, 2, 3, 3, 2, 0]))

# %%
# Read csv file 
iris_data = np.genfromtxt('irisdata.csv', delimiter=',', skip_header=1, usecols=(), dtype=None)

# %%
iris_data
# Out:
# array([( 5.1,  3.5,  1.4,  0.2, b'setosa'),
#        ( 4.9,  3. ,  1.4,  0.2, b'setosa'),
#        ( 4.7,  3.2,  1.3,  0.2, b'setosa'),
#        ( 4.6,  3.1,  1.5,  0.2, b'setosa'),
#        ( 5. ,  3.6,  1.4,  0.2, b'setosa'),
#        ( 5.4,  3.9,  1.7,  0.4, b'setosa'),
#        ( 4.6,  3.4,  1.4,  0.3, b'setosa'),
#        ( 5. ,  3.4,  1.5,  0.2, b'setosa'),
#        ( 4.4,  2.9,  1.4,  0.2, b'setosa'),
#        ( 4.9,  3.1,  1.5,  0.1, b'setosa'),
#        ( 5.4,  3.7,  1.5,  0.2, b'setosa'),
#        ( 4.8,  3.4,  1.6,  0.2, b'setosa'),
#        ( 4.8,  3. ,  1.4,  0.1, b'setosa'),
#        ( 4.3,  3. ,  1.1,  0.1, b'setosa'),
#        ( 5.8,  4. ,  1.2,  0.2, b'setosa'),
#        ( 5.7,  4.4,  1.5,  0.4, b'setosa'),
#        ( 5.4,  3.9,  1.3,  0.4, b'setosa'),
#        ( 5.1,  3.5,  1.4,  0.3, b'setosa'),
#        ( 5.7,  3.8,  1.7,  0.3, b'setosa'),
#        ( 5.1,  3.8,  1.5,  0.3, b'setosa'),
#        ( 5.4,  3.4,  1.7,  0.2, b'setosa'),
# ...

# %%
import csv 
iris = list(csv.reader(open('irisdata.csv'), delimiter=','))
input = np.array(iris)[:,:4].astype(np.str) 
output = np.array(iris)[:,:4] # 只给4列数据，不给出第5列 input & output
# iris
output
# Out:
# array([['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
#        ['5.1', '3.5', '1.4', '0.2'],
#        ['4.9', '3.0', '1.4', '0.2'],
#        ['4.7', '3.2', '1.3', '0.2'],
#        ['4.6', '3.1', '1.5', '0.2'],
#        ['5.0', '3.6', '1.4', '0.2'],
#        ['5.4', '3.9', '1.7', '0.4'],
#        ['4.6', '3.4', '1.4', '0.3'],
#        ['5.0', '3.4', '1.5', '0.2'],
#        ['4.4', '2.9', '1.4', '0.2'],
#        ['4.9', '3.1', '1.5', '0.1'],
#        ['5.4', '3.7', '1.5', '0.2'],
#        ['4.8', '3.4', '1.6', '0.2'],
#        ['4.8', '3.0', '1.4', '0.1'],
#        ['4.3', '3.0', '1.1', '0.1'],
#        ['5.8', '4.0', '1.2', '0.2'],
#        ['5.7', '4.4', '1.5', '0.4'],
#        ['5.4', '3.9', '1.3', '0.4'],
#        ['5.1', '3.5', '1.4', '0.3'],
#        ['5.7', '3.8', '1.7', '0.3'],
#        ['5.1', '3.8', '1.5', '0.3'],
#        ['5.4', '3.4', '1.7', '0.2'],
#        ['5.1', '3.7', '1.5', '0.4'],
#        ['4.6', '3.6', '1.0', '0.2'],
# ...
